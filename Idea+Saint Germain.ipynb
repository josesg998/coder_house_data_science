# %% [markdown]
# **Adquisición de JSON desde la web**

# %%
#Importamos las librerías necesarias
import requests
import pandas as pd
import json

# %% [markdown]
# 1.   Escribir un código que lea un JSON desde esta esta [web api](https://jsonplaceholder.typicode.com/users)

# %%
# tomamos información desde la url
response = requests.get('https://jsonplaceholder.typicode.com/users')
#chequeo de respuesta del requets
if response.status_code==200:
  print("Todo ok")
else:
  print("hay problemas")
# Out:
# Todo ok

# %% [markdown]
# 2.   Pasarlo a un DataFrame

# %%
# Pasamos el json a dataframe y vemos su forma
data = json.loads(response.text)
df = pd.DataFrame.from_dict(data)
df.head()
# Out:
#    id              name   username                      email  \
# 0   1     Leanne Graham       Bret          Sincere@april.biz
# 1   2      Ervin Howell  Antonette          Shanna@melissa.tv
# 2   3  Clementine Bauch   Samantha         Nathan@yesenia.net
# 3   4  Patricia Lebsack   Karianne  Julianne.OConner@kory.org
# 4   5  Chelsey Dietrich     Kamren   Lucio_Hettinger@annie.ca
#
#                                              address                  phone  \
# 0  {'street': 'Kulas Light', 'suite': 'Apt. 556',...  1-770-736-8031 x56442
# 1  {'street': 'Victor Plains', 'suite': 'Suite 87...    010-692-6593 x09125
# 2  {'street': 'Douglas Extension', 'suite': 'Suit...         1-463-123-4447
# 3  {'street': 'Hoeger Mall', 'suite': 'Apt. 692',...      493-170-9623 x156
# 4  {'street': 'Skiles Walks', 'suite': 'Suite 351...          (254)954-1289
#
#          website                                            company
# 0  hildegard.org  {'name': 'Romaguera-Crona', 'catchPhrase': 'Mu...
# 1  anastasia.net  {'name': 'Deckow-Crist', 'catchPhrase': 'Proac...
# 2    ramiro.info  {'name': 'Romaguera-Jacobson', 'catchPhrase': ...
# 3       kale.biz  {'name': 'Robel-Corkery', 'catchPhrase': 'Mult...
# 4   demarco.info  {'name': 'Keebler LLC', 'catchPhrase': 'User-c...

# %% [markdown]
# Se observa que hay dos columnas que contienen json, así que vamos a intentar transformarlas en varias columnas.

# %%
# Vemos los valores de estas dos columnas
print(df["address"][0])
print(df["company"][0])
# Out:
# {'street': 'Kulas Light', 'suite': 'Apt. 556', 'city': 'Gwenborough', 'zipcode': '92998-3874', 'geo': {'lat': '-37.3159', 'lng': '81.1496'}}
# {'name': 'Romaguera-Crona', 'catchPhrase': 'Multi-layered client-server neural-net', 'bs': 'harness real-time e-markets'}

# %%
# Extraemos de cada columna cada uno de sus valores para convertirlos en columnas
for i in ["street","suite","city","zipcode","geo"]:
  df[i] = df['address'].transform(lambda x:x[i])
for i in ["name","catchPhrase","bs"]:
  df[i] = df["company"].transform(lambda x:x[i])

#Vemos lo que obtuvimos
df.head()
# Out:
#    id                name   username                      email  \
# 0   1     Romaguera-Crona       Bret          Sincere@april.biz
# 1   2        Deckow-Crist  Antonette          Shanna@melissa.tv
# 2   3  Romaguera-Jacobson   Samantha         Nathan@yesenia.net
# 3   4       Robel-Corkery   Karianne  Julianne.OConner@kory.org
# 4   5         Keebler LLC     Kamren   Lucio_Hettinger@annie.ca
#
#                                              address                  phone  \
# 0  {'street': 'Kulas Light', 'suite': 'Apt. 556',...  1-770-736-8031 x56442
# 1  {'street': 'Victor Plains', 'suite': 'Suite 87...    010-692-6593 x09125
# 2  {'street': 'Douglas Extension', 'suite': 'Suit...         1-463-123-4447
# 3  {'street': 'Hoeger Mall', 'suite': 'Apt. 692',...      493-170-9623 x156
# 4  {'street': 'Skiles Walks', 'suite': 'Suite 351...          (254)954-1289
#
#          website                                            company  \
# 0  hildegard.org  {'name': 'Romaguera-Crona', 'catchPhrase': 'Mu...
# 1  anastasia.net  {'name': 'Deckow-Crist', 'catchPhrase': 'Proac...
# 2    ramiro.info  {'name': 'Romaguera-Jacobson', 'catchPhrase': ...
# 3       kale.biz  {'name': 'Robel-Corkery', 'catchPhrase': 'Mult...
# 4   demarco.info  {'name': 'Keebler LLC', 'catchPhrase': 'User-c...
#
#               street      suite           city     zipcode  \
# 0        Kulas Light   Apt. 556    Gwenborough  92998-3874
# 1      Victor Plains  Suite 879    Wisokyburgh  90566-7771
# 2  Douglas Extension  Suite 847  McKenziehaven  59590-4157
# 3        Hoeger Mall   Apt. 692    South Elvis  53919-4257
# 4       Skiles Walks  Suite 351     Roscoeview       33263
#
#                                       geo  \
# 0   {'lat': '-37.3159', 'lng': '81.1496'}
# 1  {'lat': '-43.9509', 'lng': '-34.4618'}
# 2  {'lat': '-68.6102', 'lng': '-47.0653'}
# 3  {'lat': '29.4572', 'lng': '-164.2990'}
# 4   {'lat': '-31.8129', 'lng': '62.5342'}
#
#                                 catchPhrase  \
# 0    Multi-layered client-server neural-net
# 1            Proactive didactic contingency
# 2         Face to face bifurcated interface
# 3  Multi-tiered zero tolerance productivity
# 4      User-centric fault-tolerant solution
#
#                                      bs
# 0           harness real-time e-markets
# 1      synergize scalable supply-chains
# 2       e-enable strategic applications
# 3  transition cutting-edge web services
# 4      revolutionize end-to-end systems

# %% [markdown]
# Parece que dentro de "adress" hay un valor "geo" que puede ser subdividido en su latitud y longitud.

# %%
# Realizamos el mismo comando realizado anteriormente
for i in ["lat","lng"]:
  df[i] = df["geo"].transform(lambda x:x[i])

# %% [markdown]
# Pasos finales

# %%
# Borramos las columnas con las que trabajamos
df = df.drop(['address', 'company','geo'], axis=1)

# Por último, establecemos la columna "id" como índice
df.set_index('id',inplace=True)

df.head()
# Out:
#                   name   username                      email  \
# id
# 1      Romaguera-Crona       Bret          Sincere@april.biz
# 2         Deckow-Crist  Antonette          Shanna@melissa.tv
# 3   Romaguera-Jacobson   Samantha         Nathan@yesenia.net
# 4        Robel-Corkery   Karianne  Julianne.OConner@kory.org
# 5          Keebler LLC     Kamren   Lucio_Hettinger@annie.ca
#
#                     phone        website             street      suite  \
# id
# 1   1-770-736-8031 x56442  hildegard.org        Kulas Light   Apt. 556
# 2     010-692-6593 x09125  anastasia.net      Victor Plains  Suite 879
# 3          1-463-123-4447    ramiro.info  Douglas Extension  Suite 847
# 4       493-170-9623 x156       kale.biz        Hoeger Mall   Apt. 692
# 5           (254)954-1289   demarco.info       Skiles Walks  Suite 351
#
#              city     zipcode                               catchPhrase  \
# id
# 1     Gwenborough  92998-3874    Multi-layered client-server neural-net
# 2     Wisokyburgh  90566-7771            Proactive didactic contingency
# 3   McKenziehaven  59590-4157         Face to face bifurcated interface
# 4     South Elvis  53919-4257  Multi-tiered zero tolerance productivity
# 5      Roscoeview       33263      User-centric fault-tolerant solution
#
#                                       bs       lat        lng
# id
# 1            harness real-time e-markets  -37.3159    81.1496
# 2       synergize scalable supply-chains  -43.9509   -34.4618
# 3        e-enable strategic applications  -68.6102   -47.0653
# 4   transition cutting-edge web services   29.4572  -164.2990
# 5       revolutionize end-to-end systems  -31.8129    62.5342
